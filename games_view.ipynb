# %%
import zipfile
import pandas as pd

# specify the path and name of the zip file
zip_file = "data/archive.zip"

# open and save the file unziped
with zipfile.ZipFile(zip_file) as ziped_data:
    ziped_data.extractall('/data/')

# %%
df = pd.read_csv('/data/videgames.csv', usecols = ['Origen', 'Tienda', 'Fabricante', 'Consola', 'Género', 'Título', 'Precio', 'Moneda', 'Disponibilidad'])

# %%
# ideias inicias
# preço por localização
# Preço por console
# Preço por fabricante

# %%
df
# Out:
#           Origen      Tienda Fabricante Consola       Género  \
# 0     Mediamarkt  Mediamarkt     Capcom     PS5       Acción
# 1     Mediamarkt  Mediamarkt       Sony     PS5  Plataformas
# 2     Mediamarkt  Mediamarkt    Ubisoft     PS5       Acción
# 3     Mediamarkt  Mediamarkt    Ubisoft     PS5       Acción
# 4     Mediamarkt  Mediamarkt        NaN     PS5       Terror
# ...          ...         ...        ...     ...          ...
# 3581     CD Keys    Nintendo     Capcom     NaN          NaN
# 3582     CD Keys    Nintendo   Nintendo     NaN          NaN
# 3583     CD Keys    Nintendo   Nintendo     NaN          NaN
# 3584     CD Keys    Nintendo   Nintendo     NaN          NaN
# 3585     CD Keys    Nintendo   Nintendo     NaN          NaN
#
#                                                  Título Precio Moneda  \
# 0                Resident Evil VIII: Village Lenticular  42.99    EUR
# 1                              Sackboy: A Big Adventure  59.99    EUR
# ...

# %%
import psycopg2
import os

def connect_db(database="", user="", password="", host="", port=""):
    try:
        conn = psycopg2.connect(
            database=os.environ.get(database),
            user=os.environ.get(user),
            password=os.environ.get(password),
            host=os.environ.get(host),
        )
        return conn
    except psycopg2.Error as e:
        # Handle the exception
        print("Unable to connect to the database:", e)

conn = connect_db(database="gamesdb", user="postgres", password="postgres", host="localhost", port="5432")

# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    database="gamesdb",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5432"
)

# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    database="gamesdb",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5432"
)

# Open a cursor to perform database operations
cur = conn.cursor()

# Execute a query
cur.execute("""
            CREATE TABLE games( id INT,
            origin VARCHAR(255),
            retailer VARCHAR(255),
            manufacturer VARCHAR(255),
            console VARCHAR(255),
            genre VARCHAR(255),
            title VARCHAR(255),
            price DECIMAL(10,2),
            currency VARCHAR(10),
            disponibility BOOLEAN """)

# Fetch the query results
rows = cur.fetchall()

# Close the cursor and the database connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[7], line 16
#      13 cur = conn.cursor()
#      15 # Execute a query
# ---> 16 cur.execute("SELECT * FROM your_table_name")
#      18 # Fetch the query results
#      19 rows = cur.fetchall()
#
# UndefinedTable: relation "your_table_name" does not exist
# LINE 1: SELECT * FROM your_table_name
#                       ^
